# %%
# Do not change: Number of customers each day for the last month

num_customers = [137, 147, 135, 128, 170, 174, 165, 146, 126, 159,

                 141, 148, 132, 147, 168, 153, 170, 161, 148, 152,

                 141, 151, 131, 149, 164, 163, 143, 143, 166, 171]

# TODO: Fill in values for the variables below
avg_first_seven = 0
avg_last_seven = 0
max_month = max(num_customers)
min_month = min(num_customers)

for i in range(7):
    avg_first_seven += num_customers[i]
    
avg_first_seven /= 7

for i in range(len(num_customers) - 7, len(num_customers), 1):
    print(num_customers[i])
    avg_last_seven += num_customers[i]

avg_last_seven /= 7

print(avg_first_seven, avg_last_seven, max_month, min_month)

# Do not change: Check your answer

# q2.check()

# %%
def percentage_liked(ratings):

    list_liked = [i>=4 for i in ratings]

    print(list_liked)

    # TODO: Complete the function

    percentage_liked = sum(list_liked) / len(list_liked) if list_liked else 0

    return percentage_liked



# Do not change: should return 0.5

percentage_liked([1, 2, 3, 4, 5, 4, 5, 1])



# Do not change: Check your answer

# q4.check()
