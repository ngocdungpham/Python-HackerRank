# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# AABCAAADA 3
def merge_the_tools(string, k):
    list_ = []
    for i in range(0, len(string), k):
        substr = string[i:i+k]
        list_.append(substr)
    answer = []
    for string in list_:
        str = []
        for char in string:
            if char not in str:
                str.append(char)
        
        answer.append(''.join(ket_qua))
        
    for item in answer:
        print(item)

# %%
# AABCAAADA 3
def merge_the_tools(string, k):
    list_ = []
    for i in range(0, len(string), k):
        substr = string[i:i+k]
        print(substr)
        ket_qua = list(dict.fromkeys(substr))
        print(''.join(ket_qua))

# %%
data = [3, 1, 5, 3, 2, 1, 5]

# Cách này biến List thành Dict (để lọc trùng và giữ thứ tự), 
# sau đó chuyển ngược lại thành List.
ket_qua = list(dict.fromkeys(data))

print(ket_qua)
# Kết quả: [3, 1, 5, 2]
# (Số 3, 1, 5 xuất hiện lần đầu được giữ lại, các lần sau bị bỏ qua, thứ tự y nguyên)
# Out:
# [3, 1, 5, 2]

# %%
if __name__ == '__main__':
    string, k = "AABCAAADA", 3
    merge_the_tools(string, k)
# Out:
# AAB
# AB
# CAA
# CA
# ADA
# AD
