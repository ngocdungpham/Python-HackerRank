# %%
# Trong Python có nhiều cách để làm tròn số sau dấu phẩy thập phân. Mình sẽ giải thích các cách phổ biến nhất:

# 🟢 1. Dùng hàm round()
# python
# x = 3.1415926535
# print(round(x, 2))   # 3.14
# print(round(x, 3))   # 3.142
# Tham số thứ 2 là số chữ số thập phân muốn giữ lại.

# Nếu không truyền tham số thứ 2 → làm tròn về số nguyên.

# 🟣 2. Dùng định dạng chuỗi format()
# python
# x = 3.1415926535
# print(format(x, ".2f"))  # '3.14'
# print(format(x, ".3f"))  # '3.142'
# Trả về chuỗi đã làm tròn.

# .2f nghĩa là giữ 2 chữ số sau dấu phẩy.

# 🔵 3. Dùng f-string (Python 3.6+)
# python
# x = 3.1415926535
# print(f"{x:.2f}")   # '3.14'
# print(f"{x:.3f}")   # '3.142'
# Rất tiện khi in ra kết quả có định dạng đẹp.

# 🟡 4. Dùng Decimal (chính xác cao hơn)
# python
# from decimal import Decimal, ROUND_HALF_UP

# x = Decimal("3.1415926535")
# y = x.quantize(Decimal("0.01"), rounding=ROUND_HALF_UP)
# print(y)  # 3.14
# Dùng khi cần độ chính xác cao (ví dụ tính toán tài chính).
