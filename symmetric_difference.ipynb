# %%
a = input()
my_list = a.split()
print(my_list)
# Out:
# ['5', '4', '3', '2', '1']

# %%
new_list = list(map(int, my_list))
print(new_list)
# Out:
# [5, 4, 3, 2, 1]

# %%
my_set = {1, 2}
print(my_set)
my_set = set()
print(my_set)
my_set = set([1, 2, 3, 4, 5])
print(my_set)
# Out:
# {1, 2}
# set()
# {1, 2, 3, 4, 5}

# %%
my_set.add(6)
print(my_set)
my_set.add((7, 8))
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6, (7, 8)}

# %%
my_set.update([9, 10, 21, 7.6, 8])
print(my_set)
# Out:
# {21, 7.6, 8, 9, 10}

# %%
my_set.discard(8)
print(my_set)
my_set.remove(21)
# Out:
# {21, 7.6, 9, 10}

# %%
a = {2, 4, 5, 9}
b = {2, 4, 11, 12}
c = a.union(b)
d = a.intersection(b)
e = a.difference(b)
print(c)
print(d)
print(e)
print(b)
# Out:
# {2, 4, 5, 9, 11, 12}
# {2, 4}
# {9, 5}
# {2, 11, 4, 12}

# %%
s = {1, 2, 3}
s.update([8, 9, 0.5]) # Thêm 0.5 vào

print(s)
# Kết quả có thể là: {0.5, 1, 2, 3, 8, 9} (Có vẻ đúng?)
# NHƯNG hãy thử số khác:

s2 = {1, 2}
s2.add(7.6) 
print(s2)
# Trên máy mình nó ra: {1, 2, 7.6} (Vẫn có vẻ đúng)

# THỬ VỚI CHUỖI ĐỂ THẤY RÕ NHẤT:
s3 = {"Zebra", "Apple", "Mouse"}
print(s3)
# Kết quả: {'Mouse', 'Zebra', 'Apple'} 
# -> Chữ A (Apple) lại đứng cuối cùng! Không hề sắp xếp theo ABC.
# Out:
# {0.5, 1, 2, 3, 8, 9}
# {1, 2, 7.6}
# {'Zebra', 'Mouse', 'Apple'}

# %%
my_set = {9, 10, 21, 7.6, 8}

# Cách đúng để có thứ tự
# ket_qua_sap_xep = sorted(my_set) 

# print(ket_qua_sap_xep)
print(my_set)
# Kết quả (List): [7.6, 8, 9, 10, 21] -> Chính xác 100%
# Out:
# {21, 7.6, 8, 9, 10}

# %%
# Exercise block 1
m = int(input())
a = set(map(int, input().split()))  # Chuyển thành int
print(a)
n = int(input())
b = set(map(int, input().split()))  # Chuyển thành int
print(b)
# Out:
# {9, 2, 4, 5}
# {2, 11, 4, 12}

# %%
# block 2
my_list = []
my_list.append(a.difference(b))
my_list.append(b.difference(a))
my_list = sorted(my_list[0].union(my_list[1]))
for i in my_list:
    print(i)
# Out:
# 5
# 9
# 11
# 12

# %%
symmetric_difference = a.symmetric_difference(b)
for item in sorted(symmetric_difference):
    print(item)
# Out:
# 5
# 9
# 11
# 12
