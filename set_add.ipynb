# %%
s = set("HackerRank")
print(s)
s.add("H")
print(s)
s.add("HackerRank")
print(s)
# Out:
# {'R', 'c', 'n', 'e', 'r', 'H', 'a', 'k'}
# {'R', 'c', 'n', 'e', 'r', 'H', 'a', 'k'}
# {'HackerRank', 'R', 'c', 'n', 'e', 'r', 'H', 'a', 'k'}

# %%
n = int(input())
s = set()
for i in range(n):
    country = input()
    s.add(country)
print(len(s))
# Out:
# UK
# CHINA
# FRANCE
# NEW ZEALAND
# UK
# FRANCE
# FRANCE
# 4
